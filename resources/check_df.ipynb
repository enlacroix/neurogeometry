# %%
import pandas as pd
df = pd.read_csv('resources/geom.csv')
df
# Out:
#     Номера предикатов                          Правило  \
# 0                   0                              NaN
# 1                   1                              NaN
# 2                   2                              NaN
# 3                   3                              NaN
# 4                   4                              NaN
# 5                   5                              NaN
# 6                   6                              NaN
# 7                   7                              NaN
# 8                   8                              NaN
# 9                   9                              NaN
# 10                 10                              NaN
# 11                 11           свойство средней линии
# 12                 12           свойство средней линии
# 13                 13           свойство средней линии
# 14                 14           свойство средней линии
# 15                 15  обратное свойство средней линии
# ...
