# %%
import pandas as pd
df = pd.read_csv('geom.csv')
df
# Out:
#     Номера предикатов                                            Правило  \
# 0                   0                                                NaN
# 1                   1                                                NaN
# 2                   2                                                NaN
# 3                   3                                                NaN
# 4                   4                                                NaN
# 5                   5                                                NaN
# 6                   6                                                NaN
# 7                   7                                                NaN
# 8                   8                                                NaN
# 9                   9                                  Свойство середины
# 10                 10         свойство медианы, проведенной к гипотенузе
# 11                 11                                  Свойство середины
# ...
