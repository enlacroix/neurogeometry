# %%
import pandas as pd
df = pd.read_csv('geom.csv')
df
# Out:
#     Номера предикатов                              Правило  \
# 0                   0                                  NaN
# 1                   1                    Свойство середины
# 2                   2                                  NaN
# 3                   3                    Свойство середины
# 4                   4                                  NaN
# 5                   5                    Свойство середины
# 6                   6                                  NaN
# 7                   7                    Свойство середины
# 8                   8                                  NaN
# 9                   9                    Свойство середины
# 10                 10                                  NaN
# 11                 11               свойство средней линии
# 12                 12               свойство средней линии
# 13                 13               свойство средней линии
# 14                 14               свойство средней линии
# ...

# %%
import pandas as pd
dfm = pd.read_excel('bank.xlsx')
dfm
# Out:
#    Тип                                              Текст Источник  Сложность  \
# 0    3  В окружности с центром O проведена хорда AB, н...      ЕГЭ          4
# 1    1  В прямоугольном треугольнике АВС, М - середина...      ОГЭ          2
# 2    1  В четырёхугольнике АВСD отмечены середины стор...      ЕГЭ          3
# 3    2  В треугольнике АВС угол ВАС равен 20 градусам,...   ЕГЭ(I)          2
# 4    2  В треугольнике АВС проведен отрезок АМ длины 4...      ОГЭ          3
# 5    2        На прямой АВС отрезок АМ = 8, АВ = 6, ВС =2     Эксп          1
#
#                                         П.ф. условия           П.ф. вопроса  \
# 0  cyl(A, M, O, K), Circle(O, A, B, K), Line(A, M...    [AB, BK] = [MK, BK]
# 1  Triangle(A, B, C); ort(A, C, C, B); mdp(M, A, ...        ort(M, E, B, C)
# 2  Quadrangle(A, B, C, D); mdp(M, A, D); mdp(K, B...           mdp(F, M, K)
# 3  Triangle(A, B, C); Line(M, B); SetValue(Angle(...        prl(A, C, M, B)
# ...
